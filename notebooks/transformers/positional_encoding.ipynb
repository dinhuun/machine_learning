# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
from matplotlib import pyplot as plt

from machine_learning.utils.utils_transformers import encode_positions

# %%
plt.style.use('seaborn-whitegrid')
sns.set_color_codes()

figsize = (12, 8)

# %%
n_samples = 10
z_dim = 64

Z = encode_positions(n_samples, z_dim)
print (Z.shape)
# Out:
# (10, 64)

# %%
plt.figure(figsize=figsize)
plt.pcolormesh(Z, cmap='GnBu')
plt.xlabel('latent feature')
plt.ylabel('position')
plt.colorbar()
plt.show()
